# %%
# !pip install langchain chromadb openai tiktoken pypdf
# Out:
# Requirement already satisfied: langchain in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (0.3.27)
# Collecting chromadb
#   Downloading chromadb-1.1.1-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Collecting openai
#   Downloading openai-2.3.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken
#   Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: pypdf in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (6.1.1)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.3.76)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (0.4.31)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.0.43)
# Requirement already satisfied: requests<3,>=2 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (6.0.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\sudha\appdata\roaming\python\python310\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\users\sudha\appdata\roaming\python\python310\site-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2->langchain) (2025.8.3)
# Requirement already satisfied: greenlet>=1 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Collecting build>=1.0.3 (from chromadb)
#   Downloading build-1.3.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting pybase64>=1.4.1 (from chromadb)
#   Downloading pybase64-1.4.2-cp310-cp310-win_amd64.whl.metadata (9.0 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading uvicorn-0.37.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (2.1.2)
# Collecting posthog<6.0.0,>=2.4.0 (from chromadb)
#   Downloading posthog-5.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.23.1-cp310-cp310-win_amd64.whl.metadata (5.2 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.22.1)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (1.74.0)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.19.2-py3-none-any.whl.metadata (16 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-34.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Downloading mmh3-5.2.0-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (3.11.3)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (0.28.1)
# Collecting rich>=10.11.0 (from chromadb)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\sudha\appdata\roaming\python\python310\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\sudha\appdata\roaming\python\python310\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Collecting backoff>=1.10.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog<6.0.0,>=2.4.0->chromadb)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from openai) (4.11.0)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.11.0-cp310-cp310-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: sniffio in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sudha\appdata\roaming\python\python310\site-packages (from anyio<5,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from tiktoken) (2025.9.18)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\sudha\appdata\roaming\python\python310\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting importlib-metadata>=4.6 (from build>=1.0.3->chromadb)
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb)
#   Downloading tomli-2.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting zipp>=3.20 (from importlib-metadata>=4.6->build>=1.0.3->chromadb)
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.27.1)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.40.3)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Downloading websocket_client-1.9.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2->langchain)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Downloading durationpy-0.10-py3-none-any.whl.metadata (340 bytes)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.5)
# Requirement already satisfied: sympy in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.3)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.37.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.37.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.37.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.37.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-semantic-conventions==0.58b0 (from opentelemetry-sdk>=1.2.0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->chromadb)
#   Downloading markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sudha\appdata\roaming\python\python310\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.35.3)
# Requirement already satisfied: filelock in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.6.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from typer>=0.9.0->chromadb) (8.3.0)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading httptools-0.7.1-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.1.0-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting oauthlib>=3.0.0 (from requests-oauthlib->kubernetes>=28.1.0->chromadb)
#   Downloading oauthlib-3.3.1-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sudha\appdata\local\programs\python\python310\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Downloading chromadb-1.1.1-cp39-abi3-win_amd64.whl (19.8 MB)
#    ---------------------------------------- 0.0/19.8 MB ? eta -:--:--
#    ------------- -------------------------- 6.6/19.8 MB 36.6 MB/s eta 0:00:01
#    -------------------------------- ------- 16.0/19.8 MB 41.9 MB/s eta 0:00:01
#    ---------------------------------------- 19.8/19.8 MB 35.8 MB/s  0:00:00
# Downloading posthog-5.4.0-py3-none-any.whl (105 kB)
# Downloading openai-2.3.0-py3-none-any.whl (999 kB)
#    ---------------------------------------- 0.0/999.8 kB ? eta -:--:--
#    ---------------------------------------- 999.8/999.8 kB 23.8 MB/s  0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading jiter-0.11.0-cp310-cp310-win_amd64.whl (204 kB)
# Downloading tiktoken-0.12.0-cp310-cp310-win_amd64.whl (879 kB)
#    ---------------------------------------- 0.0/879.4 kB ? eta -:--:--
#    ---------------------------------------- 879.4/879.4 kB 19.9 MB/s  0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading bcrypt-5.0.0-cp39-abi3-win_amd64.whl (150 kB)
# Downloading build-1.3.0-py3-none-any.whl (23 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading kubernetes-34.1.0-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 37.2 MB/s  0:00:00
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Downloading durationpy-0.10-py3-none-any.whl (3.9 kB)
# Downloading mmh3-5.2.0-cp310-cp310-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.23.1-cp310-cp310-win_amd64.whl (13.5 MB)
#    ---------------------------------------- 0.0/13.5 MB ? eta -:--:--
#    ----------------------------- ---------- 10.0/13.5 MB 47.8 MB/s eta 0:00:01
#    ---------------------------------------- 13.5/13.5 MB 42.3 MB/s  0:00:00
# Downloading opentelemetry_api-1.37.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.37.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.37.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.37.0-py3-none-any.whl (72 kB)
# Downloading opentelemetry_sdk-1.37.0-py3-none-any.whl (131 kB)
# Downloading opentelemetry_semantic_conventions-0.58b0-py3-none-any.whl (207 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading pybase64-1.4.2-cp310-cp310-win_amd64.whl (35 kB)
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Downloading typer-0.19.2-py3-none-any.whl (46 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.37.0-py3-none-any.whl (67 kB)
# Downloading httptools-0.7.1-cp310-cp310-win_amd64.whl (86 kB)
# Downloading watchfiles-1.1.0-cp310-cp310-win_amd64.whl (292 kB)
# Downloading websocket_client-1.9.0-py3-none-any.whl (82 kB)
# Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading oauthlib-3.3.1-py3-none-any.whl (160 kB)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml): started
#   Building wheel for pypika (pyproject.toml): finished with status 'done'
#   Created wheel for pypika: filename=pypika-0.48.9-py2.py3-none-any.whl size=53916 sha256=c99d5a19484d9303759e4831eea6013fc7f69a2d74bccfc8510d8b36ee6aff44
#   Stored in directory: c:\users\sudha\appdata\local\pip\cache\wheels\e1\26\51\d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, flatbuffers, durationpy, zipp, websockets, websocket-client, urllib3, tomli, shellingham, pyreadline3, pyproject_hooks, pybase64, overrides, opentelemetry-proto, oauthlib, mmh3, mdurl, jiter, importlib-resources, httptools, distro, bcrypt, backoff, uvicorn, opentelemetry-exporter-otlp-proto-common, markdown-it-py, importlib-metadata, humanfriendly, watchfiles, tiktoken, rich, requests-oauthlib, posthog, opentelemetry-api, coloredlogs, build, typer, opentelemetry-semantic-conventions, openai, onnxruntime, kubernetes, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-grpc, chromadb
#
#    ----------------------------------------  0/44 [pypika]
#    - --------------------------------------  2/44 [durationpy]
#    --- ------------------------------------  4/44 [websockets]
#    --- ------------------------------------  4/44 [websockets]
#    --- ------------------------------------  4/44 [websockets]
#    ---- -----------------------------------  5/44 [websocket-client]
#   Attempting uninstall: urllib3
#    ---- -----------------------------------  5/44 [websocket-client]
#     Found existing installation: urllib3 2.5.0
#    ---- -----------------------------------  5/44 [websocket-client]
#    ----- ----------------------------------  6/44 [urllib3]
#     Uninstalling urllib3-2.5.0:
#    ----- ----------------------------------  6/44 [urllib3]
#       Successfully uninstalled urllib3-2.5.0
#    ----- ----------------------------------  6/44 [urllib3]
#    ----- ----------------------------------  6/44 [urllib3]
#    ----- ----------------------------------  6/44 [urllib3]
#    ----- ----------------------------------  6/44 [urllib3]
#    ------- --------------------------------  8/44 [shellingham]
#    -------- -------------------------------  9/44 [pyreadline3]
#    -------- -------------------------------  9/44 [pyreadline3]
#    --------- ------------------------------ 10/44 [pyproject_hooks]
#    ---------- ----------------------------- 12/44 [overrides]
#    ----------- ---------------------------- 13/44 [opentelemetry-proto]
#    ------------ --------------------------- 14/44 [oauthlib]
#    ------------ --------------------------- 14/44 [oauthlib]
#    ------------ --------------------------- 14/44 [oauthlib]
#    ------------ --------------------------- 14/44 [oauthlib]
#    -------------- ------------------------- 16/44 [mdurl]
#    ---------------- ----------------------- 18/44 [importlib-resources]
#    ---------------- ----------------------- 18/44 [importlib-resources]
#    ------------------- -------------------- 21/44 [bcrypt]
#    -------------------- ------------------- 23/44 [uvicorn]
#    -------------------- ------------------- 23/44 [uvicorn]
#    -------------- ------------ 24/44 [opentelemetry-exporter-otlp-proto-common]
#    ---------------------- ----------------- 25/44 [markdown-it-py]
#    ---------------------- ----------------- 25/44 [markdown-it-py]
#    ---------------------- ----------------- 25/44 [markdown-it-py]
#    ----------------------- ---------------- 26/44 [importlib-metadata]
#    ------------------------ --------------- 27/44 [humanfriendly]
#    ------------------------- -------------- 28/44 [watchfiles]
#    -------------------------- ------------- 29/44 [tiktoken]
#    --------------------------- ------------ 30/44 [rich]
#    --------------------------- ------------ 30/44 [rich]
#    --------------------------- ------------ 30/44 [rich]
#    --------------------------- ------------ 30/44 [rich]
#    --------------------------- ------------ 30/44 [rich]
#    ---------------------------- ----------- 31/44 [requests-oauthlib]
#    ----------------------------- ---------- 32/44 [posthog]
#    ----------------------------- ---------- 32/44 [posthog]
#    ----------------------------- ---------- 32/44 [posthog]
#    ------------------------------ --------- 33/44 [opentelemetry-api]
#    ------------------------------ --------- 33/44 [opentelemetry-api]
#    ------------------------------ --------- 34/44 [coloredlogs]
#    ------------------------------- -------- 35/44 [build]
#    -------------------------------- ------- 36/44 [typer]
#    --------------------------- ----- 37/44 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 37/44 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 37/44 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 37/44 [opentelemetry-semantic-conventions]
#    --------------------------- ----- 37/44 [opentelemetry-semantic-conventions]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ---------------------------------- ----- 38/44 [openai]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ----------------------------------- ---- 39/44 [onnxruntime]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------ --- 40/44 [kubernetes]
#    ------------------------------------- -- 41/44 [opentelemetry-sdk]
#    ------------------------------------- -- 41/44 [opentelemetry-sdk]
#    ------------------------------------- -- 41/44 [opentelemetry-sdk]
#    --------------------------- - 42/44 [opentelemetry-exporter-otlp-proto-grpc]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------  43/44 [chromadb]
#    ---------------------------------------- 44/44 [chromadb]
#
# Successfully installed backoff-2.2.1 bcrypt-5.0.0 build-1.3.0 chromadb-1.1.1 coloredlogs-15.0.1 distro-1.9.0 durationpy-0.10 flatbuffers-25.9.23 httptools-0.7.1 humanfriendly-10.0 importlib-metadata-8.7.0 importlib-resources-6.5.2 jiter-0.11.0 kubernetes-34.1.0 markdown-it-py-4.0.0 mdurl-0.1.2 mmh3-5.2.0 oauthlib-3.3.1 onnxruntime-1.23.1 openai-2.3.0 opentelemetry-api-1.37.0 opentelemetry-exporter-otlp-proto-common-1.37.0 opentelemetry-exporter-otlp-proto-grpc-1.37.0 opentelemetry-proto-1.37.0 opentelemetry-sdk-1.37.0 opentelemetry-semantic-conventions-0.58b0 overrides-7.7.0 posthog-5.4.0 pybase64-1.4.2 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 rich-14.2.0 shellingham-1.5.4 tiktoken-0.12.0 tomli-2.3.0 typer-0.19.2 urllib3-2.3.0 uvicorn-0.37.0 watchfiles-1.1.0 websocket-client-1.9.0 websockets-15.0.1 zipp-3.23.0

# %%
from langchain_huggingface import ChatHuggingFace,HuggingFaceEmbeddings
from langchain.vectorstores import Chroma

# %%
from langchain.schema import Document

doc1 = Document(
        page_content="Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.",
        metadata={"team": "Royal Challengers Bangalore"}
    )
doc2 = Document(
        page_content="Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
        metadata={"team": "Mumbai Indians"}
    )
doc3 = Document(
        page_content="MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.",
        metadata={"team": "Chennai Super Kings"}
    )
doc4 = Document(
        page_content="Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.",
        metadata={"team": "Mumbai Indians"}
    )
doc5 = Document(
        page_content="Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.",
        metadata={"team": "Chennai Super Kings"}
    )

# %%
docs = [doc1, doc2, doc3, doc4, doc5]

# %%
vector_store=Chroma(
    embedding_function=HuggingFaceEmbeddings(),
    persist_directory='chroma_db',
    collection_name='sample'
)
# Out:
# C:\Users\sudha\AppData\Local\Temp\ipykernel_13352\3806217163.py:1: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vector_store=Chroma(

# %%
#add documents
vector_store.add_documents(docs)
# Out:
# ['6d865b34-62a1-47c0-b7ad-7bd33255b336',
#  'dad2d278-1f91-4e43-a694-dc0b6f12d06a',
#  'ad7ae073-f742-455c-86cb-23bbdf353008',
#  '7d6ade26-a090-4368-81b6-00106dbc7574',
#  '0aed5adb-550f-49a0-814e-e72d2fe00443']

# %%
#view documents
vector_store.get(include=['embeddings','documents'
                          ,'metadatas'])
# Out:
# {'ids': ['6d865b34-62a1-47c0-b7ad-7bd33255b336',
#   'dad2d278-1f91-4e43-a694-dc0b6f12d06a',
#   'ad7ae073-f742-455c-86cb-23bbdf353008',
#   '7d6ade26-a090-4368-81b6-00106dbc7574',
#   '0aed5adb-550f-49a0-814e-e72d2fe00443'],
#  'embeddings': array([[-0.03964757, -0.00801649, -0.01412725, ...,  0.0681416 ,
#          -0.00116097, -0.02425425],
#         [-0.01992595,  0.00161875, -0.00959343, ...,  0.02433109,
#          -0.00341401, -0.01722025],
#         [-0.04256177,  0.01060327, -0.01305765, ...,  0.04738371,
#          -0.01748699,  0.00204663],
#         [-0.02734393, -0.03300864,  0.01565381, ...,  0.01462705,
#           0.01177985,  0.00556423],
#         [ 0.02301695, -0.02011724, -0.0012358 , ...,  0.02533473,
#           0.00280533, -0.05120282]]),
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
vector_store.similarity_search(
    query='who among these are a proper bowler?',
    k=2
)
# Out:
# [Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#  Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.')]

# %%
#search with similarity score
vector_store.similarity_search_with_score(
    query='who among these are a proper bowler?',
    k=2
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   1.1523431539535522),
#  (Document(metadata={'team': 'Mumbai Indians'}, page_content='Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.'),
#   1.154516339302063)]

# %%
#meta-data filtering

vector_store.similarity_search_with_score(
    query="",
    filter={"team":"Chennai Super Kings"}
)
# Out:
# [(Document(metadata={'team': 'Chennai Super Kings'}, page_content='MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.'),
#   1.8879568576812744),
#  (Document(metadata={'team': 'Chennai Super Kings'}, page_content='Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'),
#   2.0017194747924805)]

# %%
vector_store.get()
# Out:
# {'ids': ['6d865b34-62a1-47c0-b7ad-7bd33255b336',
#   'dad2d278-1f91-4e43-a694-dc0b6f12d06a',
#   'ad7ae073-f742-455c-86cb-23bbdf353008',
#   '7d6ade26-a090-4368-81b6-00106dbc7574',
#   '0aed5adb-550f-49a0-814e-e72d2fe00443'],
#  'embeddings': None,
#  'documents': ['Virat Kohli is one of the most successful and consistent batsmen in IPL history. Known for his aggressive batting style and fitness, he has led the Royal Challengers Bangalore in multiple seasons.',
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
updated_doc1=Document(
    page_content="Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
    metadata={"team": "Royal Challengers Bangalore"}
)
vector_store.update_document(document_id='6d865b34-62a1-47c0-b7ad-7bd33255b336',document=updated_doc1)

# %%
vector_store.get()
# Out:
# {'ids': ['6d865b34-62a1-47c0-b7ad-7bd33255b336',
#   'dad2d278-1f91-4e43-a694-dc0b6f12d06a',
#   'ad7ae073-f742-455c-86cb-23bbdf353008',
#   '7d6ade26-a090-4368-81b6-00106dbc7574',
#   '0aed5adb-550f-49a0-814e-e72d2fe00443'],
#  'embeddings': None,
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'MS Dhoni, famously known as Captain Cool, has led Chennai Super Kings to multiple IPL titles. His finishing skills, wicketkeeping, and leadership are legendary.',
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}

# %%
#delete

vector_store.delete(ids=['ad7ae073-f742-455c-86cb-23bbdf353008'])

# %%
vector_store.get()
# Out:
# {'ids': ['6d865b34-62a1-47c0-b7ad-7bd33255b336',
#   'dad2d278-1f91-4e43-a694-dc0b6f12d06a',
#   '7d6ade26-a090-4368-81b6-00106dbc7574',
#   '0aed5adb-550f-49a0-814e-e72d2fe00443'],
#  'embeddings': None,
#  'documents': ["Virat Kohli, the former captain of Royal Challengers Bangalore (RCB), is renowned for his aggressive leadership and consistent batting performances. He holds the record for the most runs in IPL history, including multiple centuries in a single season. Despite RCB not winning an IPL title under his captaincy, Kohli's passion and fitness set a benchmark for the league. His ability to chase targets and anchor innings has made him one of the most dependable players in T20 cricket.",
#   "Rohit Sharma is the most successful captain in IPL history, leading Mumbai Indians to five titles. He's known for his calm demeanor and ability to play big innings under pressure.",
#   'Jasprit Bumrah is considered one of the best fast bowlers in T20 cricket. Playing for Mumbai Indians, he is known for his yorkers and death-over expertise.',
#   'Ravindra Jadeja is a dynamic all-rounder who contributes with both bat and ball. Representing Chennai Super Kings, his quick fielding and match-winning performances make him a key player.'],
#  'uris': None,
#  'included': ['metadatas', 'documents'],
#  'data': None,
#  'metadatas': [{'team': 'Royal Challengers Bangalore'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Mumbai Indians'},
#   {'team': 'Chennai Super Kings'}]}
